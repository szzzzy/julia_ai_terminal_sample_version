# %% [markdown]
# # S0002 feature extraction
# 18 features, 365 source speech recordings. Re-run writes a new sibling output directory.

# %%
import subprocess
command = ['D:\\Espressif\\python_env\\idf5.5_py3.13_env\\Scripts\\python.exe', 'D:\\Espressif\\projects\\julia-fused-base\\tools\\audio_features\\extract_speech_features.py', '--input', 'D:\\Espressif\\projects\\VOICE DATA BENCHMARK\\analysis\\S0002_fft', '--output', 'D:\\Espressif\\projects\\julia-fused-base\\analysis\\speech_features_S0002_rerun', '--numpy-path', 'D:\\Espressif\\projects\\VOICE DATA BENCHMARK\\tools\\_fft_deps']
subprocess.run(command, check=True)
